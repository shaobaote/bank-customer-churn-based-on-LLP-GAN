# %%
import os
import numpy as np
import argparse
import matplotlib.pyplot as plt

x=[0,1,2,3,4,5,6,7]
mean1=[0.59,0.54,0.49,0.43,0.37,0.31,0.12,0.14]
std1=[0.02,0.02,0.04,0.02,0.02,0.04,0.08,0.10]
mean2=[0.61,0.59,0.57,0.56,0.46,0.38,0.29,0.24]
std2=[0.01,0.01,0.01,0.02,0.03,0.05,0.06,0.05]
mean3=[0.38,0.40,0.40,0.39,0.37,0.14,0.13,0.11]
std3=[0.03,0.02,0.02,0.02,0.03,0.01,0.05,0.02]
mean4=[0.62,0.60,0.58,0.55,0.47,0.38,0.32,0.28]
std4=[0.02,0.02,0.01,0.02,0.02,0.02,0.05,0.06]
mean5=[]
std5=[]

plt.figure(figsize=(5,4))
ax=plt.gca();#获得坐标轴的句柄
ax.spines['bottom'].set_linewidth(0.5);###设置底部坐标轴的粗细
ax.spines['left'].set_linewidth(0.5);####设置左边坐标轴的粗细
ax.spines['right'].set_linewidth(0.5);###设置右边坐标轴的粗细
ax.spines['top'].set_linewidth(0.5);####设置上部坐标轴的粗细

plt.tick_params(top='on', right='on', which='both') # 显示上侧和右侧的刻度
plt.rcParams['xtick.direction'] = 'in' #将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'
plt.errorbar(x,mean1,std1,elinewidth=2, fmt='o',capsize=4, capthick=1, barsabove=True,ms=6,color='c')
plt.errorbar(x,mean2,std2,elinewidth=2, fmt='p',capsize=4, capthick=1, barsabove=True,ms=6,color='g')
plt.errorbar(x,mean3,std3,elinewidth=2, fmt='s',capsize=4, capthick=1, barsabove=True,ms=4,color='b')
plt.errorbar(x,mean4,std4,elinewidth=2, fmt='v',capsize=4, capthick=1, barsabove=True,ms=6,color='r')

plt.legend(['Deep LLP','LLP-GAN','LLP-WGAN','LLP-WGAN GP','LLP-ACGAN'])
plt.xticks(x,[1,2,4,8,16,32,64,128],fontsize=10)
plt.xlim(0,7)
plt.yticks(fontsize=10)
plt.plot(x,mean1,color='c',lw=1)
plt.plot(x,mean2,color='g',lw=1)
plt.plot(x,mean3,color='b',lw=1)
plt.plot(x,mean4,color='r',lw=1)
plt.ylabel('F1 Score',fontsize=13)
plt.xlabel('Bag size',fontsize=10)
plt.savefig('F1值对比.png',dpi=300)

# %%
import os
import numpy as np
import argparse
import matplotlib.pyplot as plt

x=[0,1,2,3,4,5,6,7]
mean1=[0.84,0.80,0.76,0.72,0.68,0.66,0.53,0.50]
std1=[0.01,0.01,0.02,0.02,0.01,0.02,0.04,0.01]
mean2=[0.85,0.84,0.83,0.80,0.73,0.67,0.60,0.54]
std2=[0.01,0.01,0.01,0.02,0.02,0.02,0.07,0.05]
mean3=[0.71,0.70,0.70,0.70,0.69,0.66,0.56,0.50]
std3=[0.01,0.01,0.01,0.02,0.01,0.01,0.03,0.03]
mean4=[0.86,0.85,0.84,0.81,0.74,0.68,0.62,0.58]
std4=[0.01,0.01,0.01,0.01,0.01,0.02,0.04,0.05]
mean5=[]
std5=[]

plt.figure(figsize=(5,4))
ax=plt.gca();#获得坐标轴的句柄
ax.spines['bottom'].set_linewidth(0.5);###设置底部坐标轴的粗细
ax.spines['left'].set_linewidth(0.5);####设置左边坐标轴的粗细
ax.spines['right'].set_linewidth(0.5);###设置右边坐标轴的粗细
ax.spines['top'].set_linewidth(0.5);####设置上部坐标轴的粗细

plt.tick_params(top='on', right='on', which='both') # 显示上侧和右侧的刻度
plt.rcParams['xtick.direction'] = 'in' #将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'
plt.errorbar(x,mean1,std1,elinewidth=2, fmt='o',capsize=4, capthick=1, barsabove=True,ms=6,color='c')
plt.errorbar(x,mean2,std2,elinewidth=2, fmt='p',capsize=4, capthick=1, barsabove=True,ms=6,color='g')
plt.errorbar(x,mean3,std3,elinewidth=2, fmt='s',capsize=4, capthick=1, barsabove=True,ms=4,color='b')
plt.errorbar(x,mean4,std4,elinewidth=2, fmt='v',capsize=4, capthick=1, barsabove=True,ms=6,color='r')

plt.legend(['Deep LLP','LLP-GAN','LLP-WGAN','LLP-WGAN GP','LLP-ACGAN'],loc=3)
plt.xticks(x,[1,2,4,8,16,32,64,128],fontsize=10)
plt.xlim(0,7)
plt.yticks(fontsize=10)
plt.plot(x,mean1,color='c',lw=1)
plt.plot(x,mean2,color='g',lw=1)
plt.plot(x,mean3,color='b',lw=1)
plt.plot(x,mean4,color='r',lw=1)
plt.ylabel('AUC',fontsize=13)
plt.xlabel('Bag size',fontsize=10)
plt.savefig('AUC对比.png',dpi=300)

# %%
import os
import numpy as np
import argparse
import matplotlib.pyplot as plt

x=[0,1,2,3,4,5,6,7]
mean1=[82.51,80.36,78.42,77.38,75.66,76.69,76.39,74.84]
std1=[0.94,1.23,1.92,01.51,1.9,2,3.11,4.21]
mean2=[83.08,82.59,81.82,80.64,75.09,72.71,70.20,65.91]
std2=[0.66,1.09,0.70,1.34,1.65,1.19,2.61,2.26]
mean3=[76.47,75.92,75.43,75.33,76.29,79.11,79.61,79.63]
std3=[1.87,1.14,1.99,0.90,1.89,1.03,0.63,0.65,]
mean4=[83.07,82.69,81.78,80.82,76.74,72.59,69.62,67.90]
std4=[0.94,1.23,1.04,1.11,0.95,1.43,3.68,3.04]
mean5=[]
std5=[]

plt.figure(figsize=(5,4))
ax=plt.gca();#获得坐标轴的句柄
ax.spines['bottom'].set_linewidth(0.5);###设置底部坐标轴的粗细
ax.spines['left'].set_linewidth(0.5);####设置左边坐标轴的粗细
ax.spines['right'].set_linewidth(0.5);###设置右边坐标轴的粗细
ax.spines['top'].set_linewidth(0.5);####设置上部坐标轴的粗细

plt.tick_params(top='on', right='on', which='both') # 显示上侧和右侧的刻度
plt.rcParams['xtick.direction'] = 'in' #将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'
plt.errorbar(x,mean1,std1,elinewidth=2, fmt='o',capsize=4, capthick=1, barsabove=True,ms=6,color='c')
plt.errorbar(x,mean2,std2,elinewidth=2, fmt='p',capsize=4, capthick=1, barsabove=True,ms=6,color='g')
plt.errorbar(x,mean3,std3,elinewidth=2, fmt='s',capsize=4, capthick=1, barsabove=True,ms=4,color='b')
plt.errorbar(x,mean4,std4,elinewidth=2, fmt='v',capsize=4, capthick=1, barsabove=True,ms=6,color='r')

plt.legend(['Deep LLP','LLP-GAN','LLP-WGAN','LLP-WGAN GP','LLP-ACGAN'])
plt.xticks(x,[1,2,4,8,16,32,64,128],fontsize=10)
plt.xlim(0,7)
plt.yticks(fontsize=10)
plt.plot(x,mean1,color='c',lw=1)
plt.plot(x,mean2,color='g',lw=1)
plt.plot(x,mean3,color='b',lw=1)
plt.plot(x,mean4,color='r',lw=1)
plt.ylabel('Accuracy',fontsize=13)
plt.xlabel('Bag size',fontsize=10)
plt.savefig('ACC对比.png',dpi=300)

# %%
import os
import numpy as np
import argparse
import matplotlib.pyplot as plt

x=[0,1,2,3,4,5,6]
mean1=[0.51,0.49,0.43,0.37,0.28,0.20,0.16]
std1=[0.01,0.02,0.02,0.03,0.05,0.06,0.07]
mean2=[0.56,0.50,0.48,0.42,0.38,0.26,0.22]
std2=[0.02,0.03,0.03,0.03,0.03,0.06,0.05]
mean3=[0.60,0.58,0.51,0.45,0.41,0.32,0.29]
std3=[0.01,0.01,0.02,0.04,0.03,0.04,0.12]
mean4=[0.60,0.58,0.55,0.47,0.38,0.32,0.28]
std4=[0.02,0.01,0.02,0.02,0.02,0.05,0.06]
mean5=[0.60,0.59,0.51,0.48,0.40,0.32,0.31]
std5=[0.01,0.01,0.01,0.02,0.04,0.03,0.02]
mean6=[0.60,0.59,0.54,0.48,0.41,0.31,0.31]
std6=[0.01,0.01,0.01,0.02,0.04,0.04,0.02]

plt.figure(figsize=(5,4))
ax=plt.gca();#获得坐标轴的句柄
ax.spines['bottom'].set_linewidth(0.5);###设置底部坐标轴的粗细
ax.spines['left'].set_linewidth(0.5);####设置左边坐标轴的粗细
ax.spines['right'].set_linewidth(0.5);###设置右边坐标轴的粗细
ax.spines['top'].set_linewidth(0.5);####设置上部坐标轴的粗细

plt.tick_params(top='on', right='on', which='both') # 显示上侧和右侧的刻度
plt.rcParams['xtick.direction'] = 'in' #将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'
plt.errorbar(x,mean1,std1,elinewidth=2, fmt='o',capsize=4, capthick=1, barsabove=True,ms=6,color='c')
plt.errorbar(x,mean2,std2,elinewidth=2, fmt='p',capsize=4, capthick=1, barsabove=True,ms=6,color='g')
plt.errorbar(x,mean3,std3,elinewidth=2, fmt='s',capsize=4, capthick=1, barsabove=True,ms=4,color='b')
plt.errorbar(x,mean4,std4,elinewidth=2, fmt='v',capsize=4, capthick=1, barsabove=True,ms=6,color='r')
plt.errorbar(x,mean5,std5,elinewidth=2, fmt='^',capsize=4, capthick=1, barsabove=True,ms=6,color='purple')
plt.errorbar(x,mean6,std6,elinewidth=2, fmt='*',capsize=4, capthick=1, barsabove=True,ms=6,color='coral')

plt.legend(['0.01','0.1','1','10','100','1000'])
plt.xticks(x,[2,4,8,16,32,64,128],fontsize=10)
plt.xlim(0,6)
plt.yticks(fontsize=10)
plt.plot(x,mean1,color='c',lw=1)
plt.plot(x,mean2,color='g',lw=1)
plt.plot(x,mean3,color='b',lw=1)
plt.plot(x,mean4,color='r',lw=1)
plt.plot(x,mean5,color='purple',lw=1)
plt.plot(x,mean6,color='coral',lw=1)

plt.ylabel('F1 Score',fontsize=13)
plt.xlabel('Bag size',fontsize=10)
plt.savefig('F1值对比_超参数.png',dpi=300)

# %%
import os
import numpy as np
import argparse
import matplotlib.pyplot as plt

x=[0,1,2,3,4,5,6]
mean1=[0.79,0.76,0.73,0.69,0.60,0.54,0.53]
std1=[0.01,0.02,0.01,0.01,0.04,0.05,0.03]
mean2=[0.82,0.78,0.75,0.72,0.67,0.59,0.54]
std2=[0.01,0.02,0.02,0.02,0.02,0.07,0.03]
mean3=[0.85,0.83,0.78,0.74,0.74,0.61,0.56]
std3=[0.01,0.01,0.02,0.02,0.02,0.05,0.11]
mean4=[0.85,0.84,0.81,0.74,0.68,0.62,0.58]
std4=[0.01,0.01,0.01,0.01,0.02,0.04,0.05]
mean5=[0.84,0.83,0.80,0.75,0.68,0.62,0.62]
std5=[0.01,0.01,0.02,0.01,0.02,0.04,0.02]
mean6=[0.85,0.83,0.80,0.75,0.69,0.62,0.62]
std6=[0.01,0.01,0.02,0.01,0.02,0.05,0.02]

plt.figure(figsize=(5,4))
ax=plt.gca();#获得坐标轴的句柄
ax.spines['bottom'].set_linewidth(0.5);###设置底部坐标轴的粗细
ax.spines['left'].set_linewidth(0.5);####设置左边坐标轴的粗细
ax.spines['right'].set_linewidth(0.5);###设置右边坐标轴的粗细
ax.spines['top'].set_linewidth(0.5);####设置上部坐标轴的粗细

plt.tick_params(top='on', right='on', which='both') # 显示上侧和右侧的刻度
plt.rcParams['xtick.direction'] = 'in' #将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'
plt.errorbar(x,mean1,std1,elinewidth=2, fmt='o',capsize=4, capthick=1, barsabove=True,ms=6,color='c')
plt.errorbar(x,mean2,std2,elinewidth=2, fmt='p',capsize=4, capthick=1, barsabove=True,ms=6,color='g')
plt.errorbar(x,mean3,std3,elinewidth=2, fmt='s',capsize=4, capthick=1, barsabove=True,ms=4,color='b')
plt.errorbar(x,mean4,std4,elinewidth=2, fmt='v',capsize=4, capthick=1, barsabove=True,ms=6,color='r')
plt.errorbar(x,mean5,std5,elinewidth=2, fmt='^',capsize=4, capthick=1, barsabove=True,ms=6,color='purple')
plt.errorbar(x,mean6,std6,elinewidth=2, fmt='*',capsize=4, capthick=1, barsabove=True,ms=6,color='coral')


plt.legend(['0.01','0.1','1','10','100','1000'])
plt.xticks(x,[2,4,8,16,32,64,128],fontsize=10)
plt.xlim(0,6)
plt.yticks(fontsize=10)
plt.plot(x,mean1,color='c',lw=1)
plt.plot(x,mean2,color='g',lw=1)
plt.plot(x,mean3,color='b',lw=1)
plt.plot(x,mean4,color='r',lw=1)
plt.plot(x,mean5,color='purple',lw=1)
plt.plot(x,mean6,color='coral',lw=1)

plt.ylabel('AUC',fontsize=13)
plt.xlabel('Bag size',fontsize=10)
plt.savefig('AUC对比_超参数.png',dpi=300)

# %%
import os
import numpy as np
import argparse
import matplotlib.pyplot as plt

x=[0,1,2,3,4,5,6]
mean1=[79.18,77.08,76.36,77.69,73.61,72.87,75.39]
std1=[2.93,1.74,2.63,1.01,1.64,0.99,2.30]
mean2=[82.29,80.27,77.01,76.16,73.43,73.57,69.53]
std2=[0.59,0.41,1.65,2.13,2.23,2.31,3.01]
mean3=[83.15,81.78,77.74,75.86,69.95,69.92,70.27]
std3=[0.81,1.63,1.00,1.60,1.79,3.03,3.70]
mean4=[82.69,81.78,80.82,76.74,72.59,69.62,67.90]
std4=[1.23,1.04,1.11,0.95,1.43,3.23,3.04]
mean5=[83.32,82.65,79.98,76.07,73.38,69.47,70.87]
std5=[0.76,1.06,0.65,2.39,1.35,1.74,1.02]
mean6=[82.98,82.67,80.19,76.38,73.67,68.53,71.33]
std6=[0.80,1.05,0.47,2.50,1.57,2.55,1.21]

plt.figure(figsize=(5,4))
ax=plt.gca();#获得坐标轴的句柄
ax.spines['bottom'].set_linewidth(0.5);###设置底部坐标轴的粗细
ax.spines['left'].set_linewidth(0.5);####设置左边坐标轴的粗细
ax.spines['right'].set_linewidth(0.5);###设置右边坐标轴的粗细
ax.spines['top'].set_linewidth(0.5);####设置上部坐标轴的粗细

plt.tick_params(top='on', right='on', which='both') # 显示上侧和右侧的刻度
plt.rcParams['xtick.direction'] = 'in' #将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'
plt.errorbar(x,mean1,std1,elinewidth=2, fmt='o',capsize=4, capthick=1, barsabove=True,ms=6,color='c')
plt.errorbar(x,mean2,std2,elinewidth=2, fmt='p',capsize=4, capthick=1, barsabove=True,ms=6,color='g')
plt.errorbar(x,mean3,std3,elinewidth=2, fmt='s',capsize=4, capthick=1, barsabove=True,ms=4,color='b')
plt.errorbar(x,mean4,std4,elinewidth=2, fmt='v',capsize=4, capthick=1, barsabove=True,ms=6,color='r')
plt.errorbar(x,mean5,std5,elinewidth=2, fmt='^',capsize=4, capthick=1, barsabove=True,ms=6,color='purple')
plt.errorbar(x,mean6,std6,elinewidth=2, fmt='*',capsize=4, capthick=1, barsabove=True,ms=6,color='coral')


plt.legend(['0.01','0.1','1','10','100','1000'])
plt.xticks(x,[2,4,8,16,32,64,128],fontsize=10)
plt.xlim(0,6)
plt.yticks(fontsize=10)
plt.plot(x,mean1,color='c',lw=1)
plt.plot(x,mean2,color='g',lw=1)
plt.plot(x,mean3,color='b',lw=1)
plt.plot(x,mean4,color='r',lw=1)
plt.plot(x,mean5,color='purple',lw=1)
plt.plot(x,mean6,color='coral',lw=1)


plt.ylabel('Accuracy',fontsize=13)
plt.xlabel('Bag size',fontsize=10)
plt.savefig('ACC对比_超参数.png',dpi=300)
